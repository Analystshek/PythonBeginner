# %%
#comparison operators

# %%
10 == 50
# Out:
# False

# %%
10 != 50
# Out:
# True

# %%
x= 'vanilla'
y= 'chocolate'

x!=y
# Out:
# True

# %%
10<= 10
# Out:
# True

# %%
#logical operators

# %%
(10>50) and (50>10)
# Out:
# False

# %%
(10>50) or (50>10)
# Out:
# True

# %%
('vanilla'>'chocolate') and (50>10) #since v is greater than c
# Out:
# True

# %%
not(50>10)
# Out:
# False

# %%
#membership operators

# %%
ice_cream = 'i love chocochip ice_cream'
'love' in ice_cream
# Out:
# True

# %%
scoops = [1,2,3,4,5]
6 not in scoops
# Out:
# True

# %%
wanted_scoops = 8
wanted_scoops in scoops
# Out:
# False

# %%
if 25>10:
    print('it worked!')
# Out:
# it worked!

# %%
if 25<10:
    print('it worked!')
else:
    print("did't work")
# Out:
# did't work

# %%
if 25<10:
    print('it worked!')
elif 25<20:
    print("elif work")
elif 25<40:
    print("elif 2 work")
elif 25<50:
    print("elif 3 work")
else:
    print("did't work")
# Out:
# elif 2 work

# %%
if (25<10) or (1<3):
    print('it worked!')
elif 25<20:
    print("elif work")
elif 25<40:
    print("elif 2 work")
else:
    print("did't work")
# Out:
# it worked!

# %%
if 25<10:
    print('it worked!')
elif 25<20:
    print("elif work")
else:
    print("did't work")
# Out:
# did't work

# %%
print ( 'it worked!') if 10>12 else print("did't work")
# Out:
# did't work

# %%
if 25>10:
    print('it worked!')
    if 25<20: print("if1 work")
    if 25<40: print("if2 work")
else:
    print("did't work")
# Out:
# it worked!
# if2 work
