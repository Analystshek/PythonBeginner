# %%
print("Hello WORLD")
# Out:
# Hello WORLD

# %%
#Variables in Python

# %%
x = 22
print(x)
# Out:
# 22

# %%
type(x)
# Out:
# int

# %%
y = "chocochip"
print (y)
type(y)
# Out:
# chocochip
# str

# %%
y = 3
print(y)
# Out:
# 3

# %%
x,y,z = 1,'box',88

# %%
print(x,z)
print(y)
# Out:
# 1 88
# box

# %%
ice_cream = ['cocolate', 'vanila', 'rocky road']
x,y,z = ice_cream
print(x)
print(y)
print(z)
# Out:
# cocolate
# vanila
# rocky road

# %%
x= 'best icecream'+' vanilla'
print(x)
# Out:
# best icecream vanilla

# %%
y = 1+2
print(y)
# Out:
# 3

# %%
x= 'ice cream' 
y= 'is'
z='my favorite'
print(x,y,z)
# Out:
# ice cream is my favorite

# %%
x= 'ice cream' 
y= 2
print(x,y)
# Out:
# ice cream 2

# %%
#DATA Types

# %%
type(12)
# Out:
# int

# %%
type(12+10.25)
# Out:
# float

# %%
#boolen
type(True)
# Out:
# bool

# %%
type(2>1)
# Out:
# bool

# %%
1==1
# Out:
# True

# %%
#strings

'single quote'
# Out:
# 'single quote'

# %%
"double quote"
# Out:
# 'double quote'

# %%
multiline= """
this icecream vanquished
my longing for sweets
now i need water
"""

# %%
print(multiline)
# Out:
#
# this icecream vanquished
# my longing for sweets
# now i need water

# %%
a="hello World"

# %%
print(a[:5])
print(a[2:5])
print(a[6])
print(a[-3])
# Out:
# hello
# llo
# W
# r

# %%
a*3
# Out:
# 'hello Worldhello Worldhello World'

# %%
a+a
# Out:
# 'hello Worldhello World'

# %%
#list

[1,2,3]
# Out:
# [1, 2, 3]

# %%
['cookie dough','strawberry']
# Out:
# ['cookie dough', 'strawberry']

# %%
['cookie dough',3,['strawberry'],True]
# Out:
# ['cookie dough', 3, ['strawberry'], True]

# %%
    
ice_cream=['cookie dough','strawberry']
ice_cream.append('cocolate')
ice_cream
# Out:
# ['cookie dough', 'strawberry', 'cocolate']

# %%
ice_cream[0] = 'butter pecan'
ice_cream
# Out:
# ['butter pecan', 'strawberry', 'cocolate']

# %%
nested_list=['cookie dough',3,['strawberry','vanilla'],True]

# %%
nested_list[2][1]
# Out:
# 'vanilla'

# %%
nested_list[2]
# Out:
# ['strawberry', 'vanilla']

# %%
#tuple

tuple_scoops= (1,2,3,2,1)

# %%
type(tuple_scoops)
# Out:
# tuple

# %%
tuple_scoops[1]
# Out:
# 2

# %%
#sets

daily_pints = {1,2,3,3,45}

# %%
type(daily_pints)
# Out:
# set

# %%
print(daily_pints)
# Out:
# {1, 2, 3, 45}

# %%
elses_daily_pints={2,3,34,123,45}

# %%
print(daily_pints | elses_daily_pints)
# Out:
# {1, 2, 3, 34, 45, 123}

# %%
print(daily_pints & elses_daily_pints)
# Out:
# {2, 3, 45}

# %%
print(daily_pints - elses_daily_pints)
# Out:
# {1}

# %%
print( elses_daily_pints - daily_pints)
# Out:
# {34, 123}

# %%
print( elses_daily_pints ^ daily_pints)
# Out:
# {1, 34, 123}

# %%
#dictonaries
#key/value pair

dict_cream = {'name': ' alex', 'weekly intake': 5, 'fav ice cream':['mcc', 'chocolate']}

# %%
type(dict_cream)
# Out:
# dict

# %%
print(dict_cream)
# Out:
# {'name': ' alex', 'weekly intake': 5, 'fav ice cream': ['mcc', 'chocolate']}

# %%
dict_cream.values()
# Out:
# dict_values([' alex', 5, ['mcc', 'chocolate']])

# %%
dict_cream.keys()
# Out:
# dict_keys(['name', 'weekly intake', 'fav ice cream'])

# %%
dict_cream.keys()
# Out:
# dict_keys(['name', 'weekly intake', 'fav ice cream'])

# %%
dict_cream['name']
# Out:
# ' alex'

# %%
dict_cream['name'] = ['poppy']
print(dict_cream)
# Out:
# {'name': ['poppy'], 'weekly intake': 5, 'fav ice cream': ['mcc', 'chocolate']}

# %%
dict_cream.update({'name': ' alex', 'weekly intake': 2, 'weight': 50})
print(dict_cream)
# Out:
# {'name': ' alex', 'weekly intake': 2, 'fav ice cream': ['mcc', 'chocolate'], 'weight': 50}

# %%
del dict_cream['weight']
print(dict_cream)
# Out:
# {'name': ' alex', 'weekly intake': 2, 'fav ice cream': ['mcc', 'chocolate']}
